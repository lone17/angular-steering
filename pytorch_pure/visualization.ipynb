# %%
from pathlib import Path
import json
import numpy as np
import plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Output directory for visualizations
visualization_dir = Path("visualization/")
visualization_dir.mkdir(parents=True, exist_ok=True)

# Data directory
# data_path = Path("./output/all_tokens/")
# data_path = Path("./output/prompt_only/")
# data_path = Path("../output/all_tokens/")
# data_path = Path("../output/prompt_only/")
# data_path = Path("./output/vllm_all_tokens/")
data_path = Path("./output/vllm_prompt_only/")

is_prompt_only = "prompt_only" in str(data_path)
is_vllm = "vllm" in str(data_path)
print(f"✓ Loaded libraries")
print(f"  Visualization dir: {visualization_dir}")
print(f"  Data path: {data_path}")
# Out:
# ✓ Loaded libraries
#   Visualization dir: visualization
#   Data path: output/vllm_prompt_only

# %%
# Configuration
model_ids = [
    "Qwen2.5-3B-Instruct",
    "Qwen2.5-7B-Instruct",
    "Qwen2.5-14B-Instruct",
    "Llama-3.2-3B-Instruct",
    "Llama-3.1-8B-Instruct",
    "gemma-2-9b-it",
    "Mixtral-8x7B-Instruct-v0.1",
    "Qwen1.5-MoE-A2.7B-Chat",
]

language = "en"
data_type = "harmful"

# Whether to use adaptive mode (mode_1) files
# If False, uses non-adaptive (mode_0) files
adaptive = True

# Direction strategy to visualize ("max_sim" or "max_norm")
# This filters which direction to plot when multiple are available
direction_strategy = "max_sim"

# Create figure
num_row = (len(model_ids) + 1) // 2
num_col = min(2, len(model_ids))

fig = make_subplots(
    rows=num_row,
    cols=num_col,
    specs=[[{"type": "polar"}] * num_col] * num_row,
    subplot_titles=model_ids,
    vertical_spacing=0.05,
    horizontal_spacing=0.1,
)

# Color mapping for metrics (matching parent)
colour_map = {
    "substring_matching": plotly.colors.qualitative.Plotly[1],
    "llamaguard3": plotly.colors.qualitative.Plotly[2],
    "harmbench": plotly.colors.qualitative.Plotly[0],
}

# Angle categories (0 to 360, close the loop)
categories = list(str(i) for i in range(0, 360, 10))
categories.append(categories[0])

for idx, model_id in enumerate(model_ids):
    output_path = Path(data_path) / model_id

    # Glob pattern based on adaptive mode
    if adaptive:
        glob_pattern = f"eval-mode_1*.json"
    else:
        glob_pattern = "eval-[!(mode)(perp)]*.json"

    for file in sorted(list(output_path.glob(glob_pattern))):
        # Extract metric name
        if adaptive:
            metric = file.stem.split("-")[2]
        else:
            metric = file.stem.split("-")[1]

        # Skip llmjudge (if desired)
        if metric == "llmjudge":
            continue

        # Load evaluation data
        with open(file, "r") as f:
            eval_data = json.load(f)

        print(f"Processing {model_id}: {file.name}")

        # Extract baseline
        baseline = eval_data.get("baseline")
        if baseline is None:
            print(f"  ⚠ No baseline found")
            continue

        if isinstance(baseline, list):
            baseline = np.mean(baseline)

        # Add metric to color map if not present
        if metric not in colour_map:
            colour_map[metric] = plotly.colors.qualitative.Plotly[len(colour_map)]

        # Plot baseline as dashed circle
        fig.add_trace(
            go.Scatterpolar(
                r=[
                    (
                        1 - baseline
                        if metric in ["substring_matching", "llmjudge"]
                        else baseline
                    )
                    for _ in range(len(categories))
                ],
                theta=categories,
                name="baseline",
                line=dict(width=2, color=colour_map[metric], dash="dot"),
                mode="lines",
                opacity=0.5,
                showlegend=False,
            ),
            row=idx // num_col + 1,
            col=idx % num_col + 1,
        )

        # Find any non-baseline, non-random direction keys
        direction_keys = [
            k
            for k in eval_data.keys()
            if k != "baseline" and "dir_random" not in k and direction_strategy in k
        ]

        if not direction_keys:
            print(f"  ⚠ No direction keys found, skipping")
            continue

        # Use first available direction
        chosen_direction = direction_keys[0]
        print(f"  ✓ Using direction: {chosen_direction}")

        # Extract values for each angle
        direction_data = eval_data[chosen_direction]
        values = []

        for cat in categories[:-1]:  # Exclude last (duplicate of first)
            if cat in direction_data:
                val = direction_data[cat]
                # Convert list to mean if needed
                if isinstance(val, list):
                    val = np.mean(val)
                values.append(val)
            else:
                # Missing angle - use baseline
                values.append(baseline)

        values.append(values[0])  # Close the loop

        # Plot steered results
        fig.add_trace(
            go.Scatterpolar(
                r=(
                    [1 - v for v in values]
                    if metric in ["substring_matching", "llmjudge"]
                    else values
                ),
                theta=categories,
                name=metric,
                line=dict(width=2, color=colour_map[metric]),
                mode="lines",
                showlegend=idx == 0,
            ),
            row=idx // num_col + 1,
            col=idx % num_col + 1,
        )

    # Add feature direction marker (0° = harmful direction)
    fig.add_trace(
        go.Scatterpolar(
            r=[1.02],
            theta=[0],
            name="feature direction",
            marker=dict(size=20, symbol="arrow-right", color="black"),
            mode="markers",
            showlegend=idx == 0,
        ),
        row=idx // num_col + 1,
        col=idx % num_col + 1,
    )

# Update layout for each subplot
for i in range(len(model_ids) + 1):
    polar_key = f'polar{i if i > 0 else ""}'
    fig.update_layout(
        {
            polar_key: dict(
                radialaxis=dict(
                    visible=True,
                    dtick=0.2,
                    tickfont=dict(size=8),
                ),
                angularaxis=dict(
                    tickvals=list(range(0, 360, 30)),
                    ticktext=[f"{i}°" for i in range(0, 360, 30)],
                    tickfont=dict(size=8),
                    dtick=30,
                ),
            )
        }
    )

# A4 portrait at 96 DPI: 794 × 1123 px; scale=3 → ~288 DPI output
fig.update_layout(
    height=1123,
    width=794,
    title_text=f"Angular Steering: {'Adaptive' if adaptive else 'Always-On'} --- Mode ({direction_strategy}) --- {'Promp Only' if is_prompt_only else 'All Tokens'} --- {'vLLM' if is_vllm else 'Pytorch'}",
    showlegend=True,
    legend=dict(
        orientation="h",
        y=-0.05,
        xanchor="center",
        x=0.5,
        font=dict(size=14),
    ),
)
for annotation in fig.layout.annotations:
    annotation.update(yanchor="bottom", y=annotation.y + 0.01, font=dict(size=10))
fig.write_image(visualization_dir / f"angular_steering_{'adaptive' if adaptive else 'always_on'}_{direction_strategy}_{'prompt_only' if is_prompt_only else 'all_tokens'}_{'vllm' if is_vllm else 'pytorch'}.png", scale=3)
fig.show()
# Out:
# Processing Qwen2.5-3B-Instruct: eval-mode_1-harmbench-harmful-en.json
#   ✓ Using direction: dir_max_sim_25_mid-pca_0
# Processing Qwen2.5-3B-Instruct: eval-mode_1-llamaguard3-harmful-en.json
#   ✓ Using direction: dir_max_sim_25_mid-pca_0
# Processing Qwen2.5-3B-Instruct: eval-mode_1-substring_matching-harmful-en.json
#   ✓ Using direction: dir_max_sim_25_mid-pca_0
# Processing Qwen2.5-7B-Instruct: eval-mode_1-harmbench-harmful-en.json
#   ✓ Using direction: dir_max_sim_19_mid-pca_0
# Processing Qwen2.5-7B-Instruct: eval-mode_1-llamaguard3-harmful-en.json
#   ✓ Using direction: dir_max_sim_19_mid-pca_0
# Processing Qwen2.5-7B-Instruct: eval-mode_1-substring_matching-harmful-en.json
#   ✓ Using direction: dir_max_sim_19_mid-pca_0
# Processing Qwen2.5-14B-Instruct: eval-mode_1-harmbench-harmful-en.json
#   ✓ Using direction: dir_max_sim_37_mid-pca_0
# Processing Qwen2.5-14B-Instruct: eval-mode_1-llamaguard3-harmful-en.json
#   ✓ Using direction: dir_max_sim_37_mid-pca_0
# ...

# %% [markdown]
# ## LLM-as-a-Judge Classification Results
#
# This section visualizes the distribution of response classifications (direct, indirect, redirect, refusal) across different steering angles.

# %%
# Configuration for LLM Judge visualization
model_ids_judge = [
    "Qwen2.5-3B-Instruct",
    "Qwen2.5-7B-Instruct",
    "Qwen2.5-14B-Instruct",
    "Llama-3.2-3B-Instruct",
    "Llama-3.1-8B-Instruct",
    "gemma-2-9b-it",
]

# Color mapping for classification types
colour_map_judge = {
    "direct": "red",
    "indirect": "orange",
    "redirect": "teal",
    "refusal": "green",
}

score2label = {
    0: "refusal",
    0.25: "redirect",
    0.5: "indirect",
    0.75: "indirect",
    1: "direct",
}

# Create figure
num_row = (len(model_ids_judge) + 1) // 2
num_col = min(2, len(model_ids_judge))

fig_judge = make_subplots(
    rows=num_row,
    cols=num_col,
    specs=[[{"type": "polar"}] * num_col] * num_row,
    subplot_titles=model_ids_judge,
    vertical_spacing=0.1,
    horizontal_spacing=0.1,
)

# Angle categories
categories_judge = list(str(i) for i in range(0, 360, 10))
categories_judge.append(categories_judge[0])

for idx, model_id in enumerate(model_ids_judge):
    output_path = data_path / model_id

    # Find llmjudge file
    if adaptive:
        files = list(output_path.glob("eval-mode_1-llmjudge-*.json"))
    else:
        files = list(output_path.glob("eval-llmjudge-*.json"))

    if not files:
        print(f"⚠ No llmjudge file found for {model_id}")
        continue

    file = files[0]

    with open(file, "r") as f:
        eval_data = json.load(f)

    print(f"Processing {model_id}: {file.name}")

    # Find direction keys matching strategy
    direction_keys = [
        k
        for k in eval_data.keys()
        if k != "baseline" and "dir_random" not in k and direction_strategy in k
    ]

    if not direction_keys:
        print(f"  ⚠ No direction keys matching '{direction_strategy}'")
        continue

    chosen_direction = direction_keys[0]
    print(f"  ✓ Using direction: {chosen_direction}")

    # Extract values for each angle
    direction_data = eval_data[chosen_direction]
    values = []

    for cat in categories_judge[:-1]:  # Exclude last (duplicate of first)
        if cat in direction_data:
            values.append(direction_data[cat])
        else:
            values.append([])

    values.append(values[0])  # Close the loop

    # Plot stacked bars for each classification score
    scores = [1, 0.75, 0.25, 0]
    for v in scores:
        r = [vals.count(v) / len(vals) if vals else 0 for vals in values]
        fig_judge.add_trace(
            go.Barpolar(
                r=r,
                marker_color=colour_map_judge[score2label[v]],
                name=score2label[v],
                showlegend=idx == 0,
                marker=dict(line=dict(width=0.0)),
            ),
            row=idx // num_col + 1,
            col=idx % num_col + 1,
        )

    # Add feature direction marker
    fig_judge.add_trace(
        go.Scatterpolar(
            r=[1.02],
            theta=[0],
            name="feature direction",
            marker=dict(size=20, symbol="arrow-right", color="black"),
            mode="markers",
            showlegend=idx == 0,
        ),
        row=idx // num_col + 1,
        col=idx % num_col + 1,
    )

# Update layout
polar_config = dict(
    bargap=0,
    hole=0,
    angularaxis=dict(
        tickvals=list(range(0, 360, 10)),
        ticktext=[f"{i}°" for i in range(0, 360, 10)],
        tickfont=dict(size=12),
        dtick=10,
    ),
    radialaxis=dict(showticklabels=False, showline=False),
)

# Apply to all subplots
for i in range(len(model_ids_judge) + 1):
    polar_key = f'polar{i if i > 0 else ""}'
    fig_judge.update_layout({polar_key: polar_config})

fig_judge.update_layout(
    height=800 * num_row,
    width=1000,
    title_text=f"LLM Judge Classifications: {'Adaptive' if adaptive else 'Always-On'} Mode ({direction_strategy})",
    showlegend=True,
    legend=dict(
        orientation="h",
        y=-0.05,
        xanchor="center",
        x=0.5,
        font=dict(size=14),
    ),
)

fig_judge.show()
# Out:
# ⚠ No llmjudge file found for Qwen2.5-3B-Instruct
# ⚠ No llmjudge file found for Qwen2.5-7B-Instruct
# ⚠ No llmjudge file found for Qwen2.5-14B-Instruct
# ⚠ No llmjudge file found for Llama-3.2-3B-Instruct
# ⚠ No llmjudge file found for Llama-3.1-8B-Instruct
# ⚠ No llmjudge file found for gemma-2-9b-it

# %% [markdown]
# ## Adaptive Angular Steering on tinyBenchmark
#
# This section shows performance on various benchmark tasks across different steering angles.

# %%
import os
from glob import glob
from collections import defaultdict
import plotly.express as px

# Base directory for benchmarks
base_dir = f"../benchmarks/{direction_strategy}/"

# Dictionary to map tasks to their primary metric(s)
task_to_metrics = {
    "tinyArc": ["acc_norm,none"],
    "tinyGSM8k": ["exact_match,strict-match", "exact_match,flexible-extract"],
    "tinyHellaswag": ["acc_norm,none"],
    "tinyMMLU": ["acc_norm,none"],
    "tinyTruthfulQA": ["acc,none"],
    "tinyWinogrande": ["acc_norm,none"],
}

models_bench = [
    "Qwen2.5-3B-Instruct",
    "Qwen2.5-7B-Instruct",
    "Qwen2.5-14B-Instruct",
    "Llama-3.2-3B-Instruct",
    "Llama-3.1-8B-Instruct",
    "gemma-2-9b-it",
]

# Collect data
results = defaultdict(lambda: defaultdict(dict))
baselines = defaultdict(dict)
found_metrics = defaultdict(set)

if os.path.exists(base_dir):
    for task_dir in os.listdir(base_dir):
        task_path = os.path.join(base_dir, task_dir)
        if not os.path.isdir(task_path):
            continue

        for model_dir in os.listdir(task_path):
            if model_dir not in models_bench:
                continue

            model_path = os.path.join(task_path, model_dir)
            if not os.path.isdir(model_path):
                continue

            metrics = task_to_metrics.get(task_dir, [])
            if not metrics:
                continue

            # Find results files for each angle
            for degree in list(range(0, 360, 10)) + ["none"]:
                pattern = os.path.join(
                    model_path, f"adaptive_{degree}", "*", "results_*.json"
                )
                result_files = glob(pattern)

                if not result_files:
                    continue

                result_file = sorted(result_files)[-1]

                try:
                    with open(result_file, "r") as f:
                        data = json.load(f)

                    for metric in metrics:
                        if task_dir == "tinyGSM8k":
                            metric_type = (metric.split(",")[1]).split("-")[0]
                            display_name = f"{task_dir} ({metric_type})"
                        else:
                            display_name = task_dir

                        if (
                            task_dir in data.get("results", {})
                            and metric in data["results"][task_dir]
                        ):
                            score = data["results"][task_dir][metric]
                            found_metrics[task_dir].add(metric)

                            if degree == "none":
                                baselines[model_dir][display_name] = score
                            else:
                                results[model_dir][display_name][int(degree)] = score
                except Exception as e:
                    print(f"Error processing {result_file}: {e}")

    print("Found metrics by task:")
    for task, metrics in found_metrics.items():
        print(f"  {task}: {metrics}")

    # Create visualization if data found
    if results:
        n_models = len(models_bench)
        n_cols = min(2, n_models)
        n_rows = (n_models + n_cols - 1) // n_cols

        fig_bench = make_subplots(
            rows=n_rows,
            cols=n_cols,
            specs=[[{"type": "polar"} for _ in range(n_cols)] for _ in range(n_rows)],
            subplot_titles=models_bench,
            vertical_spacing=0.1,
            horizontal_spacing=0.1,
        )

        # Add reference baseline trace
        fig_bench.add_trace(
            go.Scatterpolar(
                r=[0],
                theta=[0],
                name="baseline",
                line=dict(width=2, color="black", dash="dot"),
                mode="lines",
                opacity=0.5,
                showlegend=True,
            ),
            row=1,
            col=1,
        )

        colors = px.colors.qualitative.Plotly

        for model_idx, model_name in enumerate(models_bench):
            row = model_idx // n_cols + 1
            col = model_idx % n_cols + 1

            if model_name not in results:
                continue

            # Add feature direction marker
            fig_bench.add_trace(
                go.Scatterpolar(
                    r=[1.02],
                    theta=[0],
                    name="feature direction",
                    marker=dict(size=20, symbol="arrow-right", color="black"),
                    mode="markers",
                    showlegend=model_idx == 0,
                ),
                row=row,
                col=col,
            )

            task_color_index = 0
            sorted_tasks = sorted(results[model_name].keys())

            for task_display_name in sorted_tasks:
                task_color = colors[task_color_index % len(colors)]
                task_color_index += 1

                angles = sorted(results[model_name][task_display_name].keys())
                scores = [
                    results[model_name][task_display_name][angle] for angle in angles
                ]

                angles_closed = np.append(angles, angles[0])
                scores_closed = np.append(scores, scores[0])

                fig_bench.add_trace(
                    go.Scatterpolar(
                        r=scores_closed,
                        theta=angles_closed,
                        name=task_display_name,
                        line=dict(width=2, color=task_color),
                        mode="lines",
                        showlegend=model_idx == 0,
                    ),
                    row=row,
                    col=col,
                )

                # Add baseline
                if (
                    model_name in baselines
                    and task_display_name in baselines[model_name]
                ):
                    baseline_score = baselines[model_name][task_display_name]
                    baseline_theta = np.linspace(0, 360, 361)

                    fig_bench.add_trace(
                        go.Scatterpolar(
                            r=[baseline_score] * len(baseline_theta),
                            theta=baseline_theta,
                            line=dict(width=1.5, color=task_color, dash="dot"),
                            mode="lines",
                            opacity=0.5,
                            showlegend=False,
                        ),
                        row=row,
                        col=col,
                    )

        # Update layout
        for i in range(1, n_models + 1):
            polar_key = f'polar{i if i > 1 else ""}'
            fig_bench.update_layout(
                {
                    polar_key: dict(
                        radialaxis=dict(
                            visible=True,
                            range=[0.0, 1.02],
                            tickfont=dict(size=10),
                        ),
                        angularaxis=dict(
                            tickvals=list(range(0, 360, 30)),
                            tickfont=dict(size=10),
                            dtick=30,
                        ),
                    )
                }
            )

        fig_bench.update_layout(
            height=800 * n_rows,
            width=1000,
            title_text=f"tinyBenchmark Performance: {'Adaptive' if adaptive else 'Always-On'} Mode ({direction_strategy})",
            showlegend=True,
            legend=dict(
                orientation="h",
                y=-0.05,
                xanchor="center",
                x=0.5,
                font=dict(size=12),
            ),
        )

        fig_bench.show()
    else:
        print("⚠ No benchmark data found")
else:
    print(f"⚠ Benchmark directory not found: {base_dir}")
# Out:
# Found metrics by task:
#   tinyGSM8k: {'exact_match,strict-match', 'exact_match,flexible-extract'}
#   tinyWinogrande: {'acc_norm,none'}
#   tinyTruthfulQA: {'acc,none'}
#   tinyArc: {'acc_norm,none'}
#   tinyMMLU: {'acc_norm,none'}
#   tinyHellaswag: {'acc_norm,none'}

# %% [markdown]
# ## Perplexity Scores
#
# This section compares perplexity scores across different steering angles, comparing adaptive vs non-adaptive modes.

# %%
def filter_perplexity(perplexity_data, threshold=100):
    """Filter perplexity data to remove outliers."""
    return [p for p in perplexity_data if p < threshold]


models_ppl = [
    "Qwen2.5-3B-Instruct",
    "Qwen2.5-7B-Instruct",
    "Qwen2.5-14B-Instruct",
    "Llama-3.2-3B-Instruct",
    "Llama-3.1-8B-Instruct",
    "gemma-2-9b-it",
]

# Find perplexity files
perplexity_files = list(data_path.glob("*/eval-perplexity.json"))
all_perplexity_data = {}
for perplexity_file in perplexity_files:
    model_name = perplexity_file.parent.name
    if model_name in models_ppl:
        with open(perplexity_file, "r") as f:
            all_perplexity_data[model_name] = json.load(f)

if all_perplexity_data:
    first_model = list(all_perplexity_data.keys())[0]
    n_models = len(models_ppl)
    n_cols = min(2, n_models)
    n_rows = (n_models + n_cols - 1) // n_cols

    fig_ppl = make_subplots(
        rows=n_rows,
        cols=n_cols,
        specs=[[{"type": "polar"} for _ in range(n_cols)] for _ in range(n_rows)],
        subplot_titles=models_ppl,
        vertical_spacing=0.05,
        horizontal_spacing=0.1,
    )

    # Add reference baseline trace
    fig_ppl.add_trace(
        go.Scatterpolar(
            r=[0],
            theta=[0],
            name="no steering",
            line=dict(width=2, color="black", dash="dot"),
            mode="lines",
            opacity=0.5,
            showlegend=True,
        ),
        row=1,
        col=1,
    )

    colors = px.colors.qualitative.Plotly

    for model_idx, model_id in enumerate(models_ppl):
        if model_id not in all_perplexity_data:
            continue

        perplexity_data = all_perplexity_data[model_id]
        row = model_idx // n_cols + 1
        col = model_idx % n_cols + 1

        # Extract modes matching direction strategy
        modes = []
        for key in perplexity_data.keys():
            if direction_strategy not in key:
                continue
            if key.startswith("harmful-en") and not key.endswith("baseline"):
                mode = "non-adaptive" if "rotated" in key else "adaptive"
                modes.append((key, mode))
        modes.sort()

        max_r = 0

        # Process each mode
        for mode_idx, (mode_key, mode_name) in enumerate(modes):
            angles = []
            mean_perplexities = []

            for angle_str, perplexities in perplexity_data[mode_key].items():
                if angle_str.isdigit() and perplexities:
                    perplexities = filter_perplexity(perplexities)
                    angle = int(angle_str)
                    mean_perp = np.mean(perplexities)
                    angles.append(angle)
                    mean_perplexities.append(mean_perp)

            if angles:
                sorted_indices = np.argsort(angles)
                angles = np.array(angles)[sorted_indices]
                mean_perplexities = np.array(mean_perplexities)[sorted_indices]

                angles_closed = np.append(angles, angles[0])
                perplexities_closed = np.append(mean_perplexities, mean_perplexities[0])

                max_r = max(max_r, max(mean_perplexities))

                fig_ppl.add_trace(
                    go.Scatterpolar(
                        r=perplexities_closed,
                        theta=angles_closed,
                        name=f"{mode_name}",
                        line=dict(width=2, color=colors[mode_idx % len(colors)]),
                        mode="lines",
                        showlegend=model_idx == 0,
                    ),
                    row=row,
                    col=col,
                )

        # Add feature direction marker
        if max_r > 0:
            fig_ppl.add_trace(
                go.Scatterpolar(
                    r=[max_r * 1.02],
                    theta=[0],
                    name="feature direction",
                    marker=dict(size=20, symbol="arrow-right", color="black"),
                    mode="markers",
                    showlegend=model_idx == 0,
                ),
                row=row,
                col=col,
            )

            # Add baseline if available
            if "harmful-en-baseline" in perplexity_data:
                baseline_perplexity = np.mean(perplexity_data["harmful-en-baseline"])
                baseline_theta = np.linspace(0, 360, 100)

                fig_ppl.add_trace(
                    go.Scatterpolar(
                        r=[baseline_perplexity] * len(baseline_theta),
                        theta=baseline_theta,
                        line=dict(width=1.5, color="black", dash="dot"),
                        mode="lines",
                        opacity=0.5,
                        showlegend=False,
                    ),
                    row=row,
                    col=col,
                )

    # Update layout
    for i in range(1, n_models + 1):
        polar_key = f'polar{i if i > 1 else ""}'
        fig_ppl.update_layout(
            {
                polar_key: dict(
                    radialaxis=dict(
                        visible=True,
                        tickfont=dict(size=8),
                    ),
                    angularaxis=dict(
                        tickvals=list(range(0, 360, 30)),
                        ticktext=[f"{i}°" for i in range(0, 360, 30)],
                        tickfont=dict(size=8),
                        dtick=30,
                    ),
                )
            }
        )

    fig_ppl.update_layout(
        height=1123,
        width=794,
        title_text=f"Perplexity Scores ({direction_strategy}) --- {'Promp Only' if is_prompt_only else 'All Tokens'} --- {'vLLM' if is_vllm else 'Pytorch'}",
        showlegend=True,
        legend=dict(
            orientation="h",
            y=-0.05,
            xanchor="center",
            x=0.5,
            font=dict(size=14),
        ),
    )

    for annotation in fig_ppl.layout.annotations:
        annotation.update(yanchor="bottom", y=annotation.y + 0.02, font=dict(size=10))
    fig_ppl.write_image(visualization_dir / f"perplexity_{direction_strategy}_{'prompt_only' if is_prompt_only else 'all_tokens'}_{'vllm' if is_vllm else 'pytorch'}.png", scale=3)
    fig_ppl.show()
else:
    print("⚠ No perplexity data found")

# %%
#

# %%
# Debug: Check which files have direction data
print("Checking evaluation files for direction data:\n")

for model_id in model_ids:
    output_path = data_path / model_id
    if not output_path.exists():
        print(f"{model_id}: ⚠ Path not found")
        continue

    print(f"\n{model_id}:")

    # Check mode_1 files
    for file in sorted(output_path.glob("eval-mode_1-*.json")):
        with open(file, "r") as f:
            data = json.load(f)

        direction_keys = [
            k for k in data.keys() if k != "baseline" and "dir_random" not in k
        ]
        metric = file.stem.split("-")[2]

        if direction_keys:
            print(
                f"  ✓ {metric}: {len(direction_keys)} direction(s) - {direction_keys[0]}"
            )
        else:
            print(f"  ⚠ {metric}: No direction data (only baseline)")
# Out:
# Checking evaluation files for direction data:
#
#
# Qwen2.5-3B-Instruct:
#   ✓ harmbench: 1 direction(s) - dir_max_sim_25_mid-pca_0
#   ✓ llamaguard3: 1 direction(s) - dir_max_sim_25_mid-pca_0
#   ✓ substring_matching: 1 direction(s) - dir_max_sim_25_mid-pca_0
#
# Qwen2.5-7B-Instruct:
#   ✓ harmbench: 1 direction(s) - dir_max_sim_19_mid-pca_0
#   ✓ llamaguard3: 1 direction(s) - dir_max_sim_19_mid-pca_0
#   ✓ substring_matching: 1 direction(s) - dir_max_sim_19_mid-pca_0
#
# Qwen2.5-14B-Instruct:
#   ✓ harmbench: 1 direction(s) - dir_max_sim_37_mid-pca_0
#   ✓ llamaguard3: 1 direction(s) - dir_max_sim_37_mid-pca_0
#   ✓ substring_matching: 1 direction(s) - dir_max_sim_37_mid-pca_0
#
# Llama-3.2-3B-Instruct:
#   ✓ harmbench: 1 direction(s) - dir_max_sim_18_post-pca_0
#   ✓ llamaguard3: 1 direction(s) - dir_max_sim_18_post-pca_0
#   ✓ substring_matching: 1 direction(s) - dir_max_sim_18_post-pca_0
#
# Llama-3.1-8B-Instruct:
#   ✓ harmbench: 1 direction(s) - dir_max_sim_22_mid-pca_0
# ...
